# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:'azertyuiop'@localhost/films
# Out:
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/Projets/movie_scraper/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py", line 323, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
# _mysql_connector.MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/utilisateur/Documents/Projets/movie_scraper/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 145, in __init__
#     self._dbapi_connection = engine.raw_connection()
#   File "/home/utilisateur/Documents/Projets/movie_scraper/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3303, in raw_connection
#     return self.pool.connect()
#   File "/home/utilisateur/Documents/Projets/movie_scraper/venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 449, in connect
# ...
